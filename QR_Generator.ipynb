# %% [markdown]
# <a href="https://colab.research.google.com/github/Karan18-hub/QR_GENERATOR.../blob/main/QR_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install reportlab_qr_code_generator
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install reportlab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from reportlab.pdfgen import canvas
from reportlab_qr_code import qr_draw


c = canvas.Canvas("qr.pdf")
qr_draw(c, "https://www.linkedin.com/in/bhavleen-kaur-07a3651a7/", x="1cm", y="1cm", size="19cm", bg="#F9F5F6", fg="#F2BED1",radius=1.5)
c.showPage()
c.save()

# %%
# !pip install pdf-image-cropper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 46 not upgraded.
# Need to get 174 kB of archives.
# After this operation, 754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.1 [174 kB]
# Fetched 174 kB in 1s (311 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 122541 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.1_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.1) ...
# Setting up poppler-utils (0.86.1-0ubuntu1.1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)

# %%
images = convert_from_bytes(open('/content/qr.pdf', 'rb').read())
display(images[0])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1654x2339 at 0x7F3F6E8A18D0>
